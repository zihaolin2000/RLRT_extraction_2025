# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
import subprocess
import os
# python version: 3.11.9

# %%
# presets, functions

# preset values for the analysis:
#____________________________________________________________________________________________________________________
# physical constants
Z = 6
A = 12
mass_nucleon = 0.938273 # proton mass?
# mass_nucleus = 11.178
mass_nucleus = A*0.931494
alpha_fine = 1/137
mass_C12=11.178


# three-momentum bin centers
qvcenters = [0.100, 0.148, 0.167, 0.205, 0.240, 0.300, 0.380, 0.475, 0.570, 0.649, 0.756, 0.991, 1.619, 1.921, 2.213, 2.500, 2.783, 3.500]
# three-momentum edges
qvbins = [0.063, 0.124, 0.158, 0.186, 0.223, 0.270, 0.340, 0.428, 0.523, 0.609, 0.702, 0.878, 1.302, 1.770, 2.067, 2.357, 2.642, 2.923, 4.500]
# four-momentum squared bin names, in string format
qvbin_names = ['[0.063,0.124]', '[0.124,0.158]', '[0.158,0.186]', '[0.186,0.223]', '[0.223,0.270]', '[0.270,0.340]', '[0.340,0.428]', '[0.428,0.523]', '[0.523,0.609]',
                '[0.609,0.702]', '[0.702,0.878]', '[0.878,1.302]', '[1.302,1.770]', '[1.770,2.067]', '[2.067,2.357]', '[2.357,2.642]', '[2.642,2.923]', '[2.923,4.500]']

# four-momentum squared bin centers
Q2centers = [0.010, 0.020, 0.026, 0.040, 0.056, 0.093, 0.120, 0.160, 0.265, 0.380, 0.500, 0.800, 1.250, 1.750, 2.250, 2.750, 3.250, 3.750]
# four-momentum squared bin edges
Q2bins = [0.004, 0.015, 0.025, 0.035, 0.045, 0.070, 0.100, 0.145, 0.206, 0.322, 0.438, 0.650, 1.050, 1.500, 2.000, 2.500, 3.000, 3.500, 4.000]
# four-momentum squared bin names, in string format
Q2bin_names = ['[0.004,0.015]', '[0.015,0.025]', '[0.025,0.035]', '[0.035,0.045]', '[0.045,0.070]', '[0.070,0.100]', '[0.100,0.145]', '[0.145,0.206]', '[0.206,0.322]',
                '[0.322,0.438]', '[0.438,0.650]', '[0.650,1.050]', '[1.050,1.500]', '[1.500,2.000]', '[2.000,2.500]', '[2.500,3.000]', '[3.000,3.500]', '[3.500,4.000]']

# # map from data set index to data set name (author, year, etc.)
# dataSet_to_name = {1:"Barreau:1983ht", 2:"O'Connell:198", 3:"Sealock:1989nx", 4:"Baran:1988tw", 5:"Bagdasaryan:1988hp", 6:"Dai - HallA:2019da", 
#     7:"Arrington:1995hs", 8:"Day:1993md", 9:"Arrington:1998psnoCC", 10:"Gaskell:2008", 11:"Whitney:1974hr", 12:"AlsamiJan05", 13:"VaheJun07", 
#     14:"Gomez74", 15:"Fomin", 16:"Yamaguchi73", 17:"Ryan84", 18:"Cyzyk:1963zz", 19:"Bounin63", 20:"Photo-Daphne", 
#     # 21:"Spamer70", 
#     21:"Antony-Spies:1970jjs",
#     22:"Goldemberg64", 
#     23:"DeForrest65", 24:"Donnelly68", 25:"Barreau:French",26:"GENIE:LFG",27:"GENIE:SUSA"}


dataSet_to_name = {1:"Barreau:1983ht", 2:"O'Connell:198", 3:"Sealock:1989nx", 4:"Baran:1988tw", 5:"Bagdasaryan:1988hp", 6:"Dai - HallA:2019da", 
    7:"Arrington:1995hs", 8:"Day:1993md", 9:"Arrington:1998psnoCC", 10:"Gaskell:2008", 11:"Whitney:1974hr", 12:"AlsamiJan05", 13:"VaheJun07", 
    14:"Gomez74", 15:"Fomin", 16:"Yamaguchi73", 17:"Ryan84", 18:"Cyzyk:1963zz", 19:"Bounin63", 20:"Photo-Daphne", 
    # 21:"Spamer70", 
    21:"Antony-Spies:1970jjs",
    22:"Goldemberg64", 
    23:"DeForrest65", 24:"Mihovilovic:2024ymj", 25:"CLAS-e4nu",26:"GarinoBates:1992"}

# # map from data set index to normalization factor
# dataSet_to_normalization = {1:0.99185, 2:0.97869, 3:1.0315, 4:0.99241, 5:0.98777, 6:1.0108, 7:0.97427, 8:1.0071, 9:0.98884, 10:0.99340, 11:1.0149, 
#                 12:0.99812, 13:1.0029, 14:1.0125, 15:1.0046, 16:1.0019, 
#                 # 17:1.0517, 
#                 17:1.1, 
                
#                 # 18:1.0, 
#                 18:1.2,
#                 19:1.1500, 20:0.99754, 21:0.95, 22:1.1, 23:0.9, 24:1.0, 
#                 25:0.99185,26:1.0,27:1.0}
# # map from data set index to normalization error
# dataSet_to_normError = {1:0.24320E-02, 2:0.86008E-02, 
#                         # 3:0.48305E-02,
#                         3:0.1,
#                         4:0.45501E-02, 5:0.82797E-02, 6:0.52969E-02, 7:0.13229E-01, 8:0.33307E-02, 
#         9:0.34432E-02, 10:0.50742E-02, 11:0.15258E-01, 12:0.67079E-03, 13:0.69905E-03, 14:0.14875E-01, 15:0.30856E-02, 16:0.29024E-02, 
#         17:0.13049E-01, 
#         18:0.2, 
#         19:0.23, 20:0.10513, 21:0.25, 22:0.1, 23:0.1, 24:0.1, 25:0.002432, 26:0.0, 27:0.0}
# dataSet_to_normalization = {1:0.9373, 2:0.9491, 3:1.07, 4:0.9893, 
#                             5:0.9268, 
#                             # 5:1, 
#                             6:1.015, 7:0.9466, 8:1.029, 9:0.9739, 10:0.9838, 
#                             11:1.013, 12:1.003, 13:1.039, 14:1.0125, 15:1.023, 
#                             16:0.9455, 17:1.125, 18:1.237, 19:1.159, 20:0.99754, 
#                             21:0.95, 22:1.109, 23:0.9, 24:1.0, 25:1., 26:1.0, 27:1.0}

# dataSet_to_normError = {1:0.01032, 2:0.007411, 3:0.1, 4:0.003917, 
#                         5:0.008409,
#                         # 5:0.08,
#                         6:0.005376, 7:0.01139, 8:0.007352, 9:0.005809, 10:0.007813, 
#                         11:0.01173, 12:0.001986, 13:0.00277, 14:0.14875E-01, 15:0.007146, 
#                         16:0.003127, 17:0.01016, 18:0.2, 19:0.23, 20:0.10513, 
#                         21:0.25, 22:0.1, 23:0.1, 24:0.1, 25:0.0, 26:0.0, 27:0.0}



# March 12:
dataSet_to_normalization = {
    1:0.9701,
    2:0.9507,
    3:1.075,
    4:1.002,
    5:0.9124,
    6:1.0149,
    7:0.9502,
    8:1.026,
    9:0.9888,
    10:0.9846,
    11:1.034,
    12:0.9956,
    13:1.011,
    14:1.0125,
    15:1.0046,
    16:1.0019,
    17:1.1255,
    18:1.2369,
    19:1.22,
    20:1.0,
    21:0.95,
    22:1.1095,
    23:1.0931,
    24:1.03,
    25:0.85,
    26:1.0
}

dataSet_to_normError = {
    1:0.002,
    2:0.0006,
    3:0.0037,
    4:0.0033,
    5:0.0083,
    6:0.0060,
    7:0.0096,
    8:0.0035,
    9:0.0034,
    10:0.0066,
    11:0.013,
    12:0.0009,
    13:0.0018,
    14:0.0149,
    15:0.0031,
    16:0.0029,
    17:0.0130,
    18:0.2,
    19:0.23,
    20:0,
    21:0.25,
    22:0.1,
    23:0.1,
    24:0.02,
    25:0.02,
    26:0.02,
}
#


def round_sig_3(x):
    return '%s' % float('%.3g' % x)

def append_row(df, row):
    return pd.concat([df, pd.DataFrame([row], columns=row.index)]).reset_index(drop=True)

def linear_model(x, a, b):
    return a * x + b

def Vcoul(A=12,Z=6):
    HBARC  = 0.197327      # in GeV.fm
    ALPHA  = 1.0/137.0
    C_ASTE = 0.775
    R0     = 1.1*A**(1./3.) + 0.86*A**(-1./3.)

    # Coulomb potential at the center of the nucleus
    V0  = (3./2.)*ALPHA*HBARC*(Z-1.)/R0  # in GeV

    # Average potential
    V  = C_ASTE*V0      # from Eur. Phys. J. A26 (2005) 167
    return V

def prepare_df(filepath):
    # read the csv file:
    df = pd.read_csv(filepath)

    if 'error' not in df.columns:
        df['error']=0.0


    # calculate normalized cross section:
    if 'dataSet' not in df.columns:
        df['normalization']=1
        df['normError']=0
    else:
        df["normalization"]=df["dataSet"].map(dataSet_to_normalization)
        df["normError"]=df["dataSet"].map(dataSet_to_normError)
    df['normCross'] = df['cross'] * df['normalization']
    

    
    # system_err = 0.02
    system_err = 0.0

    df['error'] = np.sqrt(df['error']**2 + ((system_err*df['cross'])**2))
    df['normCrossError']=df['normCross']*np.sqrt((df['error']/df['cross'])**2+(df['normError']/df['normalization'])**2)
    
    # calculate the kinematic variables:
    df["ThetaRad"]=df["ThetaDeg"]*np.pi/180
    df["sin2(T/2)"]=(np.sin(df["ThetaRad"]/2))**2
    df["cos2(T/2)"]=(np.cos(df["ThetaRad"]/2))**2
    df["tan2(T/2)"]=(np.tan(df["ThetaRad"]/2))**2

    # df["nu_elastic"]=df["E0"]-df["E0"]/(1+2*df["E0"]*df["sin2(T/2)"]/mass_C12)
    # df["Ex"]=df["nu"]-df["nu_elastic"]
    df["nuel"]=df["E0"]-df["E0"]/(1+2*df["E0"]*df["sin2(T/2)"]/mass_C12)
    df["Ex"]=df["nu"]-df["nuel"]
    df["Ex"] = df["nu"] - (df["E0"]-df["E0"]/(1+2*df["E0"]*df["sin2(T/2)"]/mass_C12))

    # R = 2.894, Z = 6, A = 12
    df["R"]=1.1*(df["A"])**(1/3)+0.86/((df["A"])**(1/3))
    

    # Data:
    # df["Veff"]=Vcoul(A=12,Z=6)
    df["Veff"]=0.0031
    

    # GENIE:
    # df["Veff"]=0.0
    
    
    df["Eeff"]=df["E0"]+df["Veff"]
    df["Ep"]=df["E0"]-df["nu"]
    df["Ep_eff"]=df["Ep"]+df["Veff"]

    df["F2foc"]=(df["Eeff"]/df["E0"])**2
    df["Q2"]=4*df["E0"]*(df["Ep"])*df["sin2(T/2)"]
    df["Q2eff"]=4*df["Eeff"]*df["Ep_eff"]*df["sin2(T/2)"]
    df["qv2"]=df["nu"]**2+df["Q2eff"]
    df["qv"]=np.sqrt(df["qv2"])

    df["W2"]=mass_nucleon**2+2*mass_nucleon*df["nu"]-df["Q2eff"]
    df["epsilon"]=1/(1+2*(1+(df["nu"]**2)/df["Q2eff"])*df["tan2(T/2)"]) 

    df["gamma"]=alpha_fine*df["Ep_eff"]*(df["W2"]-mass_nucleon**2)/((4*((np.pi)**2)*df["Q2eff"]*mass_nucleon*df["E0"])*(1-df["epsilon"]))
    df["Sig_R"]=df["normCross"]/df["gamma"]
    df["D_sig_R"]=df["error"]/df["gamma"]
    df["Sig_mott"]=4*(alpha_fine**2)*(df["Ep"]**2)*df["cos2(T/2)"]/(df["Q2"]**2)
    df["Sig_mott_eff"]=df["Sig_mott"]*df["E0"]/df["Eeff"]

    # Calculate the Rosenbluth quantity:
    df["H"]=(df["qv2"]**2)/(4*(alpha_fine**2)*(df["Ep_eff"]**2)*(df["cos2(T/2)"]+2*(df["qv2"]/df["Q2eff"])*df["sin2(T/2)"]))
    df["Hcc"]=df["H"] / df["F2foc"]
    df["Hstar_Sig(nb)"]=df["H"]*df["normCross"]
    df["Hstar_error(nb)"]=df["H"]*df["normCrossError"]
    df["Hstar_Sig(GeV)"]=df["Hstar_Sig(nb)"]/((0.1973269**2)*10000000)
    df["Hstar_error(GeV)"]=df["Hstar_error(nb)"]/((0.1973269**2)*10000000)
    df["Hcc_Sig(nb)"]=df["Hcc"]*df["normCross"]
    df["Hcc_error(nb)"]=df["Hcc"]*df["normCrossError"]
    df["Hcc_Sig(GeV)"]=df["Hcc_Sig(nb)"]/((0.1973269**2)*10000000)
    df["Hcc_error(GeV)"]=df["Hcc_error(nb)"]/((0.1973269**2)*10000000)
    # we will fit "Hcc_Sig(GeV)" vs "epsilon" to the linear model to get the Rosenbluth slope and intercept

    # subdivide the data into bins
    df['qvbin'] = 0
    df['qvcenter'] = 0
    df['Q2bin'] = 0
    df['Q2center'] = 0
    df["qvbin"]=pd.cut(x=df["qv"],bins=qvbins,labels=qvbin_names,right=True)
    df["qvcenter"]=pd.cut(x=df["qv"],bins=qvbins,labels=qvcenters,right=True)
    df['qvcenter']=pd.to_numeric(df['qvcenter'])
    df["Q2bin"]=pd.cut(x=df["Q2eff"],bins=Q2bins,labels=Q2bin_names,right=True)
    df["Q2center"]=pd.cut(x=df["Q2eff"],bins=Q2bins,labels=Q2centers,right=True)
    # df["Q2bin"]=pd.cut(x=df["Q2"],bins=Q2bins,labels=Q2bin_names,right=True)
    # df["Q2center"]=pd.cut(x=df["Q2"],bins=Q2bins,labels=Q2centers,right=True)
    df['Q2center']=pd.to_numeric(df['Q2center'])
    df=df.dropna()
    # now every row of data has a bin (Q2/qv) label

    return df

# %%
# read csv file
# df = prepare_df('Data/C12_Oct29.csv')
# df = prepare_df('Data/C12_Nov12.csv')
# df = prepare_df('Data/C12_25Feb24.csv')
# df=prepare_df('Data/C12_Yamaguchi_correct40.csv')
# df = prepare_df('Data/C12_25Mar14.csv')
# df = prepare_df('Data/12C_allCS_newdatafile.csv')
df = prepare_df('Data/C12-CS-fakedata-CBfit.csv')

df
# Out:
# Empty DataFrame
# Columns: [A, Z, E0, ThetaDeg, nu, cross, error, normalization, normError, normCross, normCrossError, ThetaRad, sin2(T/2), cos2(T/2), tan2(T/2), nuel, Ex, R, Veff, Eeff, Ep, Ep_eff, F2foc, Q2, Q2eff, qv2, qv, W2, epsilon, gamma, Sig_R, D_sig_R, Sig_mott, Sig_mott_eff, H, Hcc, Hstar_Sig(nb), Hstar_error(nb), Hstar_Sig(GeV), Hstar_error(GeV), Hcc_Sig(nb), Hcc_error(nb), Hcc_Sig(GeV), Hcc_error(GeV), qvbin, qvcenter, Q2bin, Q2center]
# Index: []
#
# [0 rows x 48 columns]

# %%
# (skip )calculate bc_qv_nu (archived old centering)

# response_columns = ['qv','q2','ex','nu','RTTOT','RLTOT','RTQE','RLQE','RTIE','RLIE','RTE','RLE','RTNS','RLNS']
response_columns = ['i','RTTOT','RLTOT','RTnoNS','RLnoNS']

df[['qvcenter','nu']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_qv_nu', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_qvc_nu'] = df.index.map(df_response.set_index('i')['RLnoNS']) # qvc: qv at bin center
df['RT_qvc_nu'] = df.index.map(df_response.set_index('i')['RTnoNS']) # qvd: qv of data

df[['qv','nu']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_qv_nu', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_qvd_nu'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_qvd_nu'] = df.index.map(df_response.set_index('i')['RTnoNS'])

print('RL RT qv_nu done.')




# calculate bc_qv_ex
df[['qvcenter','Ex']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_qv_ex', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_qvc_ex'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_qvc_ex'] = df.index.map(df_response.set_index('i')['RTnoNS'])

df[['qv','Ex']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_qv_ex', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_qvd_ex'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_qvd_ex'] = df.index.map(df_response.set_index('i')['RTnoNS'])
print('RL RT qv_ex done.')




# calculate bc_qv_w2
df[['qvcenter','W2']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_qv_w2', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_qvc_w2'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_qvc_w2'] = df.index.map(df_response.set_index('i')['RTnoNS'])

df[['qv','W2']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_qv_w2', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_qvd_w2'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_qvd_w2'] = df.index.map(df_response.set_index('i')['RTnoNS'])

print('RL RT qv_w2 done.')



# calculate bc_q2_nu
df[['Q2center','nu']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_q2_nu', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_q2c_nu'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_q2c_nu'] = df.index.map(df_response.set_index('i')['RTnoNS'])

df[['Q2eff','nu']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_q2_nu', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_q2d_nu'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_q2d_nu'] = df.index.map(df_response.set_index('i')['RTnoNS'])

print('RL RT q2_nu done.')



# calculate bc_q2_ex
df[['Q2center','Ex']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_q2_ex', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_q2c_ex'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_q2c_ex'] = df.index.map(df_response.set_index('i')['RTnoNS'])

df[['Q2eff','Ex']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_q2_ex', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_q2d_ex'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_q2d_ex'] = df.index.map(df_response.set_index('i')['RTnoNS'])

print('RL RT q2_ex done.')




# calculate bc_q2_w2
df[['Q2center','W2']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_q2_w2', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_q2c_w2'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_q2c_w2'] = df.index.map(df_response.set_index('i')['RTnoNS'])

df[['Q2eff','W2']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_q2_w2', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_q2d_w2'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_q2d_w2'] = df.index.map(df_response.set_index('i')['RTnoNS'])

print('RL RT q2_w2 done.')
# Out:
# RL RT qv_nu done.
# RL RT qv_ex done.
# RL RT qv_w2 done.
# RL RT q2_nu done.
# RL RT q2_ex done.
# RL RT q2_w2 done.

# %%
# (skip) determine bin-centering corrections (archived)
df["bc_qv_nu"]=1.0
df["bc_qv_ex"]=1.0
df["bc_qv_w2"]=1.0
df["bc_q2_nu"]=1.0
df["bc_q2_ex"]=1.0
df["bc_q2_w2"]=1.0
for qvcenter in qvcenters:
    picked = df.loc[df["qvcenter"]==qvcenter]
    for index, row in picked.iterrows():
        if row['qvcenter']!= float('NaN') and row['Ex']>=0.025:
            try:
               df.loc[index, 'bc_qv_nu']= (row['epsilon']*row['RL_qvc_nu']+0.5*((qvcenter**2)/(qvcenter**2-row['nu']**2))*row['RT_qvc_nu']
                    )/(row['epsilon']*row['RL_qvd_nu']+0.5*(row['qv2']/row['Q2eff'])*row['RT_qvd_nu'])
            except ZeroDivisionError:
                print('ZeroDivisionError, index:',index)
            
            try:
                df.loc[index, 'bc_qv_ex']= (row['epsilon']*row['RL_qvc_ex']+0.5*((qvcenter**2)/(qvcenter**2-row['nu']**2))*row['RT_qvc_ex']
                    )/(row['epsilon']*row['RL_qvd_ex']+0.5*(row['qv2']/row['Q2eff'])*row['RT_qvd_ex'])
            except ZeroDivisionError:
                print('ZeroDivisionError, index:',index)
            
            try:
               df.loc[index, 'bc_qv_w2']= (row['epsilon']*row['RL_qvc_w2']+0.5*((qvcenter**2)/(2*mass_nucleon*np.sqrt(qvcenter**2+row['W2'])-row['W2']-mass_nucleon**2)
                                                    )*row['RT_qvc_w2'])/(row['epsilon']*row['RL_qvd_w2']+0.5*(row['qv2']/row['Q2eff'])*row['RT_qvd_w2'])
            except ZeroDivisionError:
                print('ZeroDivisionError, index:',index)

for Q2center in Q2centers:
    picked = df.loc[df["Q2center"]==Q2center]
    for index, row in picked.iterrows():
        if row['Q2center']!= float('NaN') and row['Ex']>=0.025:
            df.loc[index, 'bc_q2_nu']= (row['epsilon']*row['RL_q2c_nu']+0.5*((Q2center+row["nu"]**2)/(Q2center))*row['RT_q2c_nu']
                    )/(row['epsilon']*row['RL_q2d_nu']+0.5*(row['qv2']/row['Q2eff'])*row['RT_q2d_nu'])
            
            df.loc[index, 'bc_q2_ex']= (row['epsilon']*row['RL_q2c_ex']+0.5*((Q2center+row["nu"]**2)/(Q2center))*row['RT_q2c_ex']
                    )/(row['epsilon']*row['RL_q2d_ex']+0.5*(row['qv2']/row['Q2eff'])*row['RT_q2d_ex'])

            nu = (row['W2']+Q2center-mass_nucleon**2)/(2*mass_nucleon)
            qv2center = Q2center+nu**2
            df.loc[index, 'bc_q2_w2']= (row['epsilon']*row['RL_q2c_w2']+0.5*(qv2center/(Q2center))*row['RT_q2c_w2']
                    )/(row['epsilon']*row['RL_q2d_w2']+0.5*(row['qv2']/row['Q2eff'])*row['RT_q2d_w2'])
# Out:
# ZeroDivisionError, index: 5994
# ZeroDivisionError, index: 5994
# ZeroDivisionError, index: 6175
# ZeroDivisionError, index: 6175

# %%
# fit RL RT at center, data (May 23 2025) (no nuclear states)


# response_columns = ['qv','q2','ex','nu','RTTOT','RLTOT','RTQE','RLQE','RTIE','RLIE','RTE','RLE','RTNS','RLNS']
response_columns = ['i','RTTOT','RLTOT','RTnoNS','RLnoNS']


df[['qvcenter','nu']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_qv_nu', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_qvc_nu'] = df.index.map(df_response.set_index('i')['RLnoNS']) # qvc: qv at bin center
df['RT_qvc_nu'] = df.index.map(df_response.set_index('i')['RTnoNS']) # qvd: qv of data

df[['qv','nu']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_qv_nu', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_qvd_nu'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_qvd_nu'] = df.index.map(df_response.set_index('i')['RTnoNS'])

print('RL RT qv_nu done.')




# calculate bc_qv_ex
df[['qvcenter','Ex']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_qv_ex', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_qvc_ex'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_qvc_ex'] = df.index.map(df_response.set_index('i')['RTnoNS'])

df[['qv','Ex']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_qv_ex', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_qvd_ex'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_qvd_ex'] = df.index.map(df_response.set_index('i')['RTnoNS'])
print('RL RT qv_ex done.')




# calculate bc_qv_w2
df[['qvcenter','W2']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_qv_w2', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_qvc_w2'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_qvc_w2'] = df.index.map(df_response.set_index('i')['RTnoNS'])

df[['qv','W2']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_qv_w2', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_qvd_w2'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_qvd_w2'] = df.index.map(df_response.set_index('i')['RTnoNS'])

print('RL RT qv_w2 done.')



# calculate bc_q2_nu
df[['Q2center','nu']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_q2_nu', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_q2c_nu'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_q2c_nu'] = df.index.map(df_response.set_index('i')['RTnoNS'])

df[['Q2eff','nu']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_q2_nu', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_q2d_nu'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_q2d_nu'] = df.index.map(df_response.set_index('i')['RTnoNS'])

print('RL RT q2_nu done.')



# calculate bc_q2_ex
df[['Q2center','Ex']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_q2_ex', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_q2c_ex'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_q2c_ex'] = df.index.map(df_response.set_index('i')['RTnoNS'])

df[['Q2eff','Ex']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_q2_ex', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_q2d_ex'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_q2d_ex'] = df.index.map(df_response.set_index('i')['RTnoNS'])

print('RL RT q2_ex done.')




# calculate bc_q2_w2
df[['Q2center','W2']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_q2_w2', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_q2c_w2'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_q2c_w2'] = df.index.map(df_response.set_index('i')['RTTOT'])

df[['Q2eff','W2']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_q2_w2', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
df['RL_q2d_w2'] = df.index.map(df_response.set_index('i')['RLnoNS'])
df['RT_q2d_w2'] = df.index.map(df_response.set_index('i')['RTnoNS'])

print('RL RT q2_w2 done.')
# Out:
# RL RT qv_nu done.
# RL RT qv_ex done.
# RL RT qv_w2 done.
# RL RT q2_nu done.
# RL RT q2_ex done.
# RL RT q2_w2 done.

# %%
# determine bin-centering corrections with correct epsilon

def calculate_bin_centering(df):
    def epsilon(nu=0,Q2=1,tan2=0):
        return (1+2*(1+(nu**2)/Q2)*tan2)**-1
    df["bc_qv_nu"]=1.0
    df["bc_qv_ex"]=1.0
    df["bc_qv_w2"]=1.0
    df["bc_q2_nu"]=1.0
    df["bc_q2_ex"]=1.0
    df["bc_q2_w2"]=1.0
    # df['ep_Q2center']=(1+2*(1+df['nu']**2/(df['Q2center']))*df['tan2(T/2)'])**-1
    # df['ep_qvcenter']=(1+2*(1+df['nu']**2/(df['qvcenter']**2-df['nu']**2))*df['tan2(T/2)'])**-1

    for qvcenter in qvcenters:
        picked = df.loc[df["qvcenter"]==qvcenter]
        for index, row in picked.iterrows():
            if row['qvcenter']!= float('NaN') and row['Ex']>=0.025:
                exc=row['Ex']
                w2c=row['W2']
                tan2=row['tan2(T/2)']
                try:
                    nuc=row['nu']
                    Q2c=qvcenter**2-nuc**2
                    epc=epsilon(nu=nuc,Q2=Q2c,tan2=tan2)
                    df.loc[index, 'bc_qv_nu']= (epc*row['RL_qvc_nu']+0.5*((qvcenter**2)/(Q2c))*row['RT_qvc_nu']
                        )/(row['epsilon']*row['RL_qvd_nu']+0.5*(row['qv2']/row['Q2eff'])*row['RT_qvd_nu'])
                except ZeroDivisionError:
                    print('ZeroDivisionError, index:',index)
                
                try:
                    nuc=np.sqrt(mass_C12**2+qvcenter**2+2*mass_C12*exc)-mass_C12
                    Q2c=qvcenter**2-nuc**2
                    epc=epsilon(nu=nuc,Q2=Q2c,tan2=tan2)
                    df.loc[index, 'bc_qv_ex']= (epc*row['RL_qvc_ex']+0.5*((qvcenter**2)/(Q2c))*row['RT_qvc_ex']
                        )/(row['epsilon']*row['RL_qvd_ex']+0.5*(row['qv2']/row['Q2eff'])*row['RT_qvd_ex'])
                    # df.loc[index, 'bc_qv_ex']= (row['epsilon']*row['RL_qvc_ex']+0.5*((qvcenter**2)/(qvcenter**2-row['nu']**2))*row['RT_qvc_ex']
                    #     )/(row['epsilon']*row['RL_qvd_ex']+0.5*(row['qv2']/row['Q2eff'])*row['RT_qvd_ex'])
                except ZeroDivisionError:
                    print('ZeroDivisionError, index:',index)
                
                try:
                    nuc=np.sqrt(w2c+qvcenter**2)-mass_nucleon
                    Q2c=qvcenter**2-nuc**2
                    epc=epsilon(nu=nuc,Q2=Q2c,tan2=tan2)
                    df.loc[index, 'bc_qv_w2']= (epc*row['RL_qvc_w2']+0.5*((qvcenter**2)/(Q2c))*row['RT_qvc_w2']
                        )/(row['epsilon']*row['RL_qvd_w2']+0.5*(row['qv2']/row['Q2eff'])*row['RT_qvd_w2'])
                    # df.loc[index, 'bc_qv_w2']= (row['epsilon']*row['RL_qvc_w2']+0.5*((qvcenter**2)/(2*mass_nucleon*np.sqrt(qvcenter**2+row['W2'])-row['W2']-mass_nucleon**2)
                    #                                     )*row['RT_qvc_w2'])/(row['epsilon']*row['RL_qvd_w2']+0.5*(row['qv2']/row['Q2eff'])*row['RT_qvd_w2'])
                except ZeroDivisionError:
                    print('ZeroDivisionError, index:',index)

    for Q2center in Q2centers:
        picked = df.loc[df["Q2center"]==Q2center]
        for index, row in picked.iterrows():
            exc=row['Ex']
            w2c=row['W2']
            if row['Q2center']!= float('NaN') and row['Ex']>=0.025:
                nuc=row['nu']
                tan2=row['tan2(T/2)']
                qvc2=Q2center+nuc**2
                epc=epsilon(nu=nuc,Q2=Q2center,tan2=tan2)
                df.loc[index, 'bc_q2_nu']= (epc*row['RL_q2c_nu']+0.5*(qvc2/Q2center)*row['RT_q2c_nu']
                        )/(row['epsilon']*row['RL_q2d_nu']+0.5*(row['qv2']/row['Q2eff'])*row['RT_q2d_nu'])
                # df.loc[index, 'bc_q2_nu']= (epc*row['RL_q2c_nu']+0.5*((Q2center+row["nu"]**2)/(Q2center))*row['RT_q2c_nu']
                #         )/(row['epsilon']*row['RL_q2d_nu']+0.5*(row['qv2']/row['Q2eff'])*row['RT_q2d_nu'])
                

                nuc=exc+Q2center/(2*mass_C12)
                tan2=row['tan2(T/2)']
                qvc2=Q2center+nuc**2
                epc=epsilon(nu=nuc,Q2=Q2center,tan2=tan2)
                df.loc[index, 'bc_q2_ex']= (epc*row['RL_q2c_ex']+0.5*(qvc2/Q2center)*row['RT_q2c_ex']
                        )/(row['epsilon']*row['RL_q2d_ex']+0.5*(row['qv2']/row['Q2eff'])*row['RT_q2d_ex'])
                # df.loc[index, 'bc_q2_ex']= (row['epsilon']*row['RL_q2c_ex']+0.5*((Q2center+row["nu"]**2)/(Q2center))*row['RT_q2c_ex']
                #         )/(row['epsilon']*row['RL_q2d_ex']+0.5*(row['qv2']/row['Q2eff'])*row['RT_q2d_ex'])

                nuc=(w2c+Q2center-mass_nucleon**2)/(2*mass_nucleon)
                tan2=row['tan2(T/2)']
                qvc2=Q2center+nuc**2
                epc=epsilon(nu=nuc,Q2=Q2center,tan2=tan2)
                df.loc[index, 'bc_q2_w2']= (epc*row['RL_q2c_w2']+0.5*(qvc2/Q2center)*row['RT_q2c_w2']
                        )/(row['epsilon']*row['RL_q2d_w2']+0.5*(row['qv2']/row['Q2eff'])*row['RT_q2d_w2'])

                # nu = (row['W2']+Q2center-mass_nucleon**2)/(2*mass_nucleon)
                # qv2center = Q2center+nu**2
                # df.loc[index, 'bc_q2_w2']= (row['epsilon']*row['RL_q2c_w2']+0.5*(qv2center/(Q2center))*row['RT_q2c_w2']
                #         )/(row['epsilon']*row['RL_q2d_w2']+0.5*(row['qv2']/row['Q2eff'])*row['RT_q2d_w2'])
    return df

df = calculate_bin_centering(df)
# Out:
# ZeroDivisionError, index: 5995
# ZeroDivisionError, index: 6176

# %%
# (skip) prepare for bin-centering W2c, nuc, epc (May 19 2025 new method)
df['W2Aeff']=mass_C12**2 + 2*mass_C12*df['nu']-df['Q2eff']

df['nu_Q2center'] = 0.0 
df['epsilon_Q2center'] = 0.0
df['W2_Q2center'] = 0.0

df['nu_qvcenter'] = 0.0 
df['epsilon_qvcenter'] = 0.0
df['W2_qvcenter'] = 0.0


for index, row in df.iterrows():
    tan2 = row['tan2(T/2)']
    nu=row['nu']
    W2eff = row['W2']
    W2Aeff=row['W2Aeff']

    # Q2 bin:
    Q2c = row['Q2center']
    if row['Ex']>=0.050:
        nuc = (W2eff+Q2c-mass_nucleon**2)/(2*mass_nucleon)
        epc = (1+2*(1+(nuc**2)/Q2c)*tan2)**-1
        W2c = W2eff
    else:

        nuc =  (W2Aeff+Q2c-mass_C12**2)/(2*mass_C12)
        epc = (1+2*(1+(nuc**2)/Q2c)*tan2)**-1
        W2c = mass_nucleon**2 + 2*mass_nucleon*nuc-Q2c
    df.loc[index, 'nu_Q2center'] = nuc 
    df.loc[index, 'epsilon_Q2center'] = epc
    df.loc[index, 'W2_Q2center']= W2c


    

    # qv bin:
    qvc = row['qvcenter']
    if row['Ex']>=0.050:
        nuc = np.sqrt(W2eff+qvc**2)-mass_nucleon
        Q2c=qvc**2-nuc**2
        epc = (1+2*(1+(nuc**2)/Q2c)*tan2)**-1
        W2c=W2eff
    else:
        nuc = np.sqrt(W2Aeff+qvc**2)-mass_C12 #question: M or MA?
        Q2c=qvc**2-nuc**2
        epc = (1+2*(1+(nuc**2)/Q2c)*tan2)**-1
        W2c = mass_nucleon**2 + 2*mass_nucleon*nuc - Q2c
    df.loc[index, 'nu_qvcenter'] = nuc 
    df.loc[index, 'epsilon_qvcenter'] = epc
    df.loc[index, 'W2_qvcenter']= W2c
df['Q2_qvcenter'] = df['qvcenter']**2-df['nu_qvcenter']**2
df['qv_Q2center'] = np.sqrt(df['Q2center']+df['nu_Q2center']**2)
print('done')
# Out:
# done

# %%
# (skip) fortran estimate RL, RT at (Q2, W2); (q, W2)
# response_columns = ['qv','q2','ex','nu','RTTOT','RLTOT','RTQE','RLQE','RTIE','RLIE','RTE','RLE','RTNS','RLNS']
# write(6, 2000) i, RTTOT, RLTOT, (RTQE+RTIE+RTE), (RLQE+RLIE+RLE) 
response_columns = ['i','RTTOT','RLTOT','RT_noNS','RL_noNS']

# response_columns = ['i','RTTOT','RLTOT']

# calculate bc_qv_w2
df[['qvcenter','W2_qvcenter']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_qv_w2', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])


df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)

print('len df_response, df:', len(df_response), len(df))
# df_response['RL_noNS']=df_response['RLTOT']-df_response['RLNS']
# df_response['RT_noNS']=df_response['RTTOT']-df_response['RTNS']
df['RL_qvc_w2'] = df.index.map(df_response.set_index('i')['RL_noNS'])
df['RT_qvc_w2'] = df.index.map(df_response.set_index('i')['RT_noNS'])



df[['qv','W2']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_qv_w2', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
# df_response['RL_noNS']=df_response['RLTOT']-df_response['RLNS']
# df_response['RT_noNS']=df_response['RTTOT']-df_response['RTNS']
df['RL_qvd_w2'] = df.index.map(df_response.set_index('i')['RL_noNS'])
df['RT_qvd_w2'] = df.index.map(df_response.set_index('i')['RT_noNS'])

print('RL RT qv_w2 done.')










# calculate bc_q2_w2
df[['Q2center','W2_Q2center']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_q2_w2', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
# df_response['RL_noNS']=df_response['RLTOT']-df_response['RLNS']
# df_response['RT_noNS']=df_response['RTTOT']-df_response['RTNS']
df['RL_q2c_w2'] = df.index.map(df_response.set_index('i')['RL_noNS'])
df['RT_q2c_w2'] = df.index.map(df_response.set_index('i')['RT_noNS'])



df[['Q2eff','W2']].to_csv('input.txt',index=True,header=False,sep=' ')
with open('output.txt', 'w') as output_file:
    subprocess.run(['./response_q2_w2', 'input.txt'], stdout=output_file) 
subprocess.run(['sleep', '0.5'])
df_response = pd.read_csv('output.txt', sep='\s+', header=None, names=response_columns)
# df_response['RL_noNS']=df_response['RLTOT']-df_response['RLNS']
# df_response['RT_noNS']=df_response['RTTOT']-df_response['RTNS']
df['RL_q2d_w2'] = df.index.map(df_response.set_index('i')['RL_noNS'])
df['RT_q2d_w2'] = df.index.map(df_response.set_index('i')['RT_noNS'])

print('RL RT q2_w2 done.')
# Out:
# len df_response, df: 8989 8989
# RL RT qv_w2 done.
# RL RT q2_w2 done.

# %%
# (skip) calculate bin-centering factors
df["bc_qv_w2"]=1.0
df["bc_q2_w2"]=1.0
for index, row in df.iterrows():
    if row['qvcenter']!= float('NaN'):
        try:
            df.loc[index, 'bc_qv_w2']= (row['epsilon_qvcenter']*row['RL_qvc_w2']+0.5*((row['qvcenter']**2)/row['Q2_qvcenter'])*row['RT_qvc_w2']
                        )/(row['epsilon']*row['RL_qvd_w2']+0.5*(row['qv2']/row['Q2eff'])*row['RT_qvd_w2'])
        except ZeroDivisionError:
            print('ZeroDivisionError, index:',index)

    if row['Q2center']!= float('NaN'):
        try:
            df.loc[index, 'bc_q2_w2']= (row['epsilon_Q2center']*row['RL_q2c_w2']+0.5*((row['qv_Q2center']**2)/row['Q2center'])*row['RT_q2c_w2']
                        )/(row['epsilon']*row['RL_q2d_w2']+0.5*(row['qv2']/row['Q2eff'])*row['RT_q2d_w2'])
        except ZeroDivisionError:
            print('ZeroDivisionError, index:',index,'row Ex:',row['Ex'])

            # for qvcenter in qvcenters:
#     picked = df.loc[df["qvcenter"]==qvcenter]
#     for index, row in picked.iterrows():
#         if row['qvcenter']!= float('NaN'):
#             try:
#                df.loc[index, 'bc_qv_w2']= (row['epsilon_qvcenter']*row['RL_qvc_w2']+0.5*((qvcenter**2)/(2*mass_nucleon*np.sqrt(qvcenter**2+row['W2'])-row['W2']-mass_nucleon**2)
#                                                     )*row['RT_qvc_w2'])/(row['epsilon']*row['RL_qvd_w2']+0.5*(row['qv2']/row['Q2eff'])*row['RT_qvd_w2'])
#             except ZeroDivisionError:
#                 print('ZeroDivisionError, index:',index)

# for Q2center in Q2centers:
#     picked = df.loc[df["Q2center"]==Q2center]
#     for index, row in picked.iterrows():
#         if row['Q2center']!= float('NaN'):

#             nu = (row['W2']+Q2center-mass_nucleon**2)/(2*mass_nucleon)
#             qv2center = Q2center+nu**2
#             df.loc[index, 'bc_q2_w2']= (row['epsilon']*row['RL_q2c_w2']+0.5*(qv2center/(Q2center))*row['RT_q2c_w2']
#                     )/(row['epsilon']*row['RL_q2d_w2']+0.5*(row['qv2']/row['Q2eff'])*row['RT_q2d_w2'])
# Out:
# ZeroDivisionError, index: 0
# ZeroDivisionError, index: 0 row Ex: 0.0108338681523958
# ZeroDivisionError, index: 1
# ZeroDivisionError, index: 1 row Ex: 0.015833868152395802
# ZeroDivisionError, index: 3
# ZeroDivisionError, index: 3 row Ex: -0.00018348428222682766
# ZeroDivisionError, index: 4
# ZeroDivisionError, index: 4 row Ex: 0.004816515717773173
# ZeroDivisionError, index: 5
# ZeroDivisionError, index: 5 row Ex: 0.009816515717773172
# ZeroDivisionError, index: 6
# ZeroDivisionError, index: 6 row Ex: 0.014816515717773173
# ZeroDivisionError, index: 8
# ZeroDivisionError, index: 8 row Ex: -4.9508450974046925e-05
# ZeroDivisionError, index: 9
# ZeroDivisionError, index: 9 row Ex: 0.004950491549025953
# ZeroDivisionError, index: 10
# ZeroDivisionError, index: 10 row Ex: 0.009950491549025954
# ZeroDivisionError, index: 11
# ZeroDivisionError, index: 11 row Ex: 0.014950491549025953
# ZeroDivisionError, index: 22
# ZeroDivisionError, index: 22 row Ex: 0.003154481094572824
# ZeroDivisionError, index: 23
# ZeroDivisionError, index: 23 row Ex: 0.008154481094572825
# ZeroDivisionError, index: 24
# ZeroDivisionError, index: 24 row Ex: 0.013154481094572824
# ZeroDivisionError, index: 34
# ZeroDivisionError, index: 34 row Ex: 0.012063797888700201
# ZeroDivisionError, index: 38
# ZeroDivisionError, index: 38 row Ex: 0.007250242459437764
# ZeroDivisionError, index: 39
# ZeroDivisionError, index: 39 row Ex: 0.012250242459437765
# ZeroDivisionError, index: 47
# ZeroDivisionError, index: 47 row Ex: 0.0013879052486994847
# ZeroDivisionError, index: 48
# ZeroDivisionError, index: 48 row Ex: 0.006387905248699486
# ZeroDivisionError, index: 49
# ZeroDivisionError, index: 49 row Ex: 0.011387905248699485
# ZeroDivisionError, index: 67
# ZeroDivisionError, index: 67 row Ex: 0.0036016113941382353
# ZeroDivisionError, index: 68
# ZeroDivisionError, index: 68 row Ex: 0.008601611394138235
# ZeroDivisionError, index: 69
# ZeroDivisionError, index: 69 row Ex: 0.013601611394138236
# ZeroDivisionError, index: 93
# ZeroDivisionError, index: 93 row Ex: 0.005726624606931345
# ZeroDivisionError, index: 94
# ZeroDivisionError, index: 94 row Ex: 0.010726624606931346
# ZeroDivisionError, index: 95
# ZeroDivisionError, index: 95 row Ex: 0.015726624606931347
# ZeroDivisionError, index: 106
# ZeroDivisionError, index: 106 row Ex: 0.01151988128037178
# ZeroDivisionError, index: 117
# ZeroDivisionError, index: 117 row Ex: 0.0003424010774174119
# ZeroDivisionError, index: 118
# ZeroDivisionError, index: 118 row Ex: 0.005342401077417413
# ZeroDivisionError, index: 119
# ZeroDivisionError, index: 119 row Ex: 0.010342401077417412
# ZeroDivisionError, index: 120
# ZeroDivisionError, index: 120 row Ex: 0.015342401077417411
# ZeroDivisionError, index: 140
# ZeroDivisionError, index: 140 row Ex: 0.003509443255590553
# ZeroDivisionError, index: 141
# ZeroDivisionError, index: 141 row Ex: 0.008509443255590552
# ZeroDivisionError, index: 142
# ZeroDivisionError, index: 142 row Ex: 0.013509443255590552
# ZeroDivisionError, index: 167
# ZeroDivisionError, index: 167 row Ex: -0.0005030550122355447
# ZeroDivisionError, index: 168
# ZeroDivisionError, index: 168 row Ex: 0.0044969449877644545
# ZeroDivisionError, index: 169
# ZeroDivisionError, index: 169 row Ex: 0.009496944987764454
# ZeroDivisionError, index: 170
# ZeroDivisionError, index: 170 row Ex: 0.014496944987764455
# ZeroDivisionError, index: 195
# ZeroDivisionError, index: 195 row Ex: 0.005752747575760886
# ZeroDivisionError, index: 196
# ZeroDivisionError, index: 196 row Ex: 0.010752747575760887
# ZeroDivisionError, index: 197
# ZeroDivisionError, index: 197 row Ex: 0.015752747575760884
# ZeroDivisionError, index: 229
# ZeroDivisionError, index: 229 row Ex: 0.010388342506934923
# ZeroDivisionError, index: 230
# ZeroDivisionError, index: 230 row Ex: 0.015388342506934924
# ZeroDivisionError, index: 262
# ZeroDivisionError, index: 262 row Ex: 0.004329088684492192
# ZeroDivisionError, index: 263
# ZeroDivisionError, index: 263 row Ex: 0.009329088684492193
# ZeroDivisionError, index: 264
# ZeroDivisionError, index: 264 row Ex: 0.014329088684492192
# ZeroDivisionError, index: 289
# ZeroDivisionError, index: 289 row Ex: 0.010759935428799262
# ZeroDivisionError, index: 290
# ZeroDivisionError, index: 290 row Ex: 0.015759935428799263
# ZeroDivisionError, index: 306
# ZeroDivisionError, index: 306 row Ex: 0.01425018435570528
# ZeroDivisionError, index: 346
# ZeroDivisionError, index: 346 row Ex: 0.003275772436915651
# ZeroDivisionError, index: 347
# ZeroDivisionError, index: 347 row Ex: 0.008275772436915652
# ZeroDivisionError, index: 348
# ZeroDivisionError, index: 348 row Ex: 0.013275772436915651
# ZeroDivisionError, index: 379
# ZeroDivisionError, index: 379 row Ex: -0.0007444140640083651
# ZeroDivisionError, index: 380
# ZeroDivisionError, index: 380 row Ex: 0.004255585935991634
# ZeroDivisionError, index: 381
# ZeroDivisionError, index: 381 row Ex: 0.009255585935991635
# ZeroDivisionError, index: 382
# ZeroDivisionError, index: 382 row Ex: 0.014255585935991633
# ZeroDivisionError, index: 422
# ZeroDivisionError, index: 422 row Ex: -0.0011386631407030428
# ZeroDivisionError, index: 423
# ZeroDivisionError, index: 423 row Ex: 0.003861336859296958
# ZeroDivisionError, index: 424
# ZeroDivisionError, index: 424 row Ex: 0.008861336859296957
# ZeroDivisionError, index: 425
# ZeroDivisionError, index: 425 row Ex: 0.013861336859296958
# ZeroDivisionError, index: 518
# ZeroDivisionError, index: 518 row Ex: 0.002666399216507834
# ZeroDivisionError, index: 519
# ZeroDivisionError, index: 519 row Ex: 0.007666399216507835
# ZeroDivisionError, index: 520
# ZeroDivisionError, index: 520 row Ex: 0.012666399216507834
# ZeroDivisionError, index: 612
# ZeroDivisionError, index: 612 row Ex: 0.009784840164869347
# ZeroDivisionError, index: 613
# ZeroDivisionError, index: 613 row Ex: 0.014784840164869348
# ZeroDivisionError, index: 642
# ZeroDivisionError, index: 642 row Ex: 0.009146629749738046
# ZeroDivisionError, index: 643
# ZeroDivisionError, index: 643 row Ex: 0.014146629749738047
# ZeroDivisionError, index: 699
# ZeroDivisionError, index: 699 row Ex: 0.006433953618197529
# ZeroDivisionError, index: 700
# ZeroDivisionError, index: 700 row Ex: 0.011433953618197528
# ZeroDivisionError, index: 751
# ZeroDivisionError, index: 751 row Ex: -0.0009927716686752366
# ZeroDivisionError, index: 752
# ZeroDivisionError, index: 752 row Ex: 0.004007228331324764
# ZeroDivisionError, index: 753
# ZeroDivisionError, index: 753 row Ex: 0.009007228331324765
# ZeroDivisionError, index: 754
# ZeroDivisionError, index: 754 row Ex: 0.014007228331324763
# ZeroDivisionError, index: 891
# ZeroDivisionError, index: 891 row Ex: 0.0022189215321863024
# ZeroDivisionError, index: 892
# ZeroDivisionError, index: 892 row Ex: 0.007218921532186302
# ZeroDivisionError, index: 893
# ZeroDivisionError, index: 893 row Ex: 0.012218921532186303
# ZeroDivisionError, index: 958
# ZeroDivisionError, index: 958 row Ex: 0.008595470548183205
# ZeroDivisionError, index: 959
# ZeroDivisionError, index: 959 row Ex: 0.013595470548183206
# ZeroDivisionError, index: 1018
# ZeroDivisionError, index: 1018 row Ex: -0.0004664475478888038
# ZeroDivisionError, index: 1019
# ZeroDivisionError, index: 1019 row Ex: 0.009533552452111196
# ZeroDivisionError, index: 1094
# ZeroDivisionError, index: 1094 row Ex: 0.007192696899355689
# ZeroDivisionError, index: 1133
# ZeroDivisionError, index: 1133 row Ex: 0.008815152268368188
# ZeroDivisionError, index: 1204
# ZeroDivisionError, index: 1204 row Ex: 0.0060010911634358795
# ZeroDivisionError, index: 1205
# ZeroDivisionError, index: 1205 row Ex: 0.016001091163435878
# ZeroDivisionError, index: 1295
# ZeroDivisionError, index: 1295 row Ex: 0.004690296116512661
# ZeroDivisionError, index: 1296
# ZeroDivisionError, index: 1296 row Ex: 0.01469029611651266
# ZeroDivisionError, index: 1433
# ZeroDivisionError, index: 1433 row Ex: -0.004524144474519547
# ZeroDivisionError, index: 1434
# ZeroDivisionError, index: 1434 row Ex: 0.0054758555254804525
# ZeroDivisionError, index: 1435
# ZeroDivisionError, index: 1435 row Ex: 0.015475855525480454
# ZeroDivisionError, index: 1787
# ZeroDivisionError, index: 1787 row Ex: 0.01581144859536419
# ZeroDivisionError, index: 2001
# ZeroDivisionError, index: 2001 row Ex: 0.005176730962311176
# ZeroDivisionError, index: 2067
# ZeroDivisionError, index: 2067 row Ex: 0.005392101682932898
# ZeroDivisionError, index: 2101
# ZeroDivisionError, index: 2101 row Ex: 0.015318365949038654
# ZeroDivisionError, index: 2868
# ZeroDivisionError, index: 2868 row Ex: 0.009061884184079588
# ZeroDivisionError, index: 2869
# ZeroDivisionError, index: 2869 row Ex: 0.015061884184079586
# ZeroDivisionError, index: 7002
# ZeroDivisionError, index: 7002 row Ex: 0.014011839408274144
# ZeroDivisionError, index: 7003
# ZeroDivisionError, index: 7003 row Ex: 0.014011839408274144
# ZeroDivisionError, index: 7004
# ZeroDivisionError, index: 7004 row Ex: 0.014111839408274143
# ZeroDivisionError, index: 7005
# ZeroDivisionError, index: 7005 row Ex: 0.014111839408274143
# ZeroDivisionError, index: 7006
# ZeroDivisionError, index: 7006 row Ex: 0.014311839408274143
# ZeroDivisionError, index: 7007
# ZeroDivisionError, index: 7007 row Ex: 0.014311839408274143
# ZeroDivisionError, index: 7008
# ZeroDivisionError, index: 7008 row Ex: 0.014411839408274143
# ZeroDivisionError, index: 7009
# ZeroDivisionError, index: 7009 row Ex: 0.014411839408274143
# ZeroDivisionError, index: 7010
# ZeroDivisionError, index: 7010 row Ex: 0.014511839408274142
# ZeroDivisionError, index: 7011
# ZeroDivisionError, index: 7011 row Ex: 0.014511839408274142
# ZeroDivisionError, index: 7012
# ZeroDivisionError, index: 7012 row Ex: 0.014611839408274145
# ZeroDivisionError, index: 7013
# ZeroDivisionError, index: 7013 row Ex: 0.014611839408274145
# ZeroDivisionError, index: 7014
# ZeroDivisionError, index: 7014 row Ex: 0.014711839408274145
# ZeroDivisionError, index: 7015
# ZeroDivisionError, index: 7015 row Ex: 0.014711839408274145
# ZeroDivisionError, index: 7016
# ZeroDivisionError, index: 7016 row Ex: 0.014911839408274143
# ZeroDivisionError, index: 7017
# ZeroDivisionError, index: 7017 row Ex: 0.014911839408274143
# ZeroDivisionError, index: 7018
# ZeroDivisionError, index: 7018 row Ex: 0.015111839408274142
# ZeroDivisionError, index: 7019
# ZeroDivisionError, index: 7019 row Ex: 0.015111839408274142
# ZeroDivisionError, index: 7020
# ZeroDivisionError, index: 7020 row Ex: 0.015211839408274145
# ZeroDivisionError, index: 7021
# ZeroDivisionError, index: 7021 row Ex: 0.015211839408274145
# ZeroDivisionError, index: 7022
# ZeroDivisionError, index: 7022 row Ex: 0.015411839408274144
# ZeroDivisionError, index: 7023
# ZeroDivisionError, index: 7023 row Ex: 0.015411839408274144
# ZeroDivisionError, index: 7024
# ZeroDivisionError, index: 7024 row Ex: 0.015611839408274143
# ZeroDivisionError, index: 7025
# ZeroDivisionError, index: 7025 row Ex: 0.015611839408274143
# ZeroDivisionError, index: 7026
# ZeroDivisionError, index: 7026 row Ex: 0.015711839408274142
# ZeroDivisionError, index: 7027
# ZeroDivisionError, index: 7027 row Ex: 0.015711839408274142
# ZeroDivisionError, index: 7028
# ZeroDivisionError, index: 7028 row Ex: 0.016011839408274144
# ZeroDivisionError, index: 7029
# ZeroDivisionError, index: 7029 row Ex: 0.016011839408274144
# ZeroDivisionError, index: 7030
# ZeroDivisionError, index: 7030 row Ex: 0.016211839408274142
# ZeroDivisionError, index: 7031
# ZeroDivisionError, index: 7031 row Ex: 0.016211839408274142
# ZeroDivisionError, index: 7264
# ZeroDivisionError, index: 7264 row Ex: 0.014295760743111834
# ZeroDivisionError, index: 7265
# ZeroDivisionError, index: 7265 row Ex: 0.014295760743111834
# ZeroDivisionError, index: 7266
# ZeroDivisionError, index: 7266 row Ex: 0.014395760743111833
# ZeroDivisionError, index: 7267
# ZeroDivisionError, index: 7267 row Ex: 0.014395760743111833
# ZeroDivisionError, index: 7268
# ZeroDivisionError, index: 7268 row Ex: 0.014495760743111832
# ZeroDivisionError, index: 7269
# ZeroDivisionError, index: 7269 row Ex: 0.014495760743111832
# ZeroDivisionError, index: 7270
# ZeroDivisionError, index: 7270 row Ex: 0.014595760743111832
# ZeroDivisionError, index: 7271
# ZeroDivisionError, index: 7271 row Ex: 0.014595760743111832
# ZeroDivisionError, index: 7272
# ZeroDivisionError, index: 7272 row Ex: 0.014695760743111831
# ZeroDivisionError, index: 7273
# ZeroDivisionError, index: 7273 row Ex: 0.014695760743111831
# ZeroDivisionError, index: 7274
# ZeroDivisionError, index: 7274 row Ex: 0.014895760743111833
# ZeroDivisionError, index: 7275
# ZeroDivisionError, index: 7275 row Ex: 0.014895760743111833
# ZeroDivisionError, index: 7276
# ZeroDivisionError, index: 7276 row Ex: 0.014995760743111833
# ZeroDivisionError, index: 7277
# ZeroDivisionError, index: 7277 row Ex: 0.014995760743111833
# ZeroDivisionError, index: 7278
# ZeroDivisionError, index: 7278 row Ex: 0.015095760743111832
# ZeroDivisionError, index: 7279
# ZeroDivisionError, index: 7279 row Ex: 0.015095760743111832
# ZeroDivisionError, index: 7280
# ZeroDivisionError, index: 7280 row Ex: 0.01539576074311183
# ZeroDivisionError, index: 7281
# ZeroDivisionError, index: 7281 row Ex: 0.01539576074311183
# ZeroDivisionError, index: 7282
# ZeroDivisionError, index: 7282 row Ex: 0.015495760743111833
# ZeroDivisionError, index: 7283
# ZeroDivisionError, index: 7283 row Ex: 0.015495760743111833
# ZeroDivisionError, index: 7284
# ZeroDivisionError, index: 7284 row Ex: 0.015595760743111833
# ZeroDivisionError, index: 7285
# ZeroDivisionError, index: 7285 row Ex: 0.015595760743111833
# ZeroDivisionError, index: 7286
# ZeroDivisionError, index: 7286 row Ex: 0.01579576074311183
# ZeroDivisionError, index: 7287
# ZeroDivisionError, index: 7287 row Ex: 0.01579576074311183
# ZeroDivisionError, index: 7288
# ZeroDivisionError, index: 7288 row Ex: 0.016095760743111833
# ZeroDivisionError, index: 7289
# ZeroDivisionError, index: 7289 row Ex: 0.016095760743111833
# ZeroDivisionError, index: 7290
# ZeroDivisionError, index: 7290 row Ex: 0.016195760743111833
# ZeroDivisionError, index: 7291
# ZeroDivisionError, index: 7291 row Ex: 0.016195760743111833
# ZeroDivisionError, index: 7596
# ZeroDivisionError, index: 7596 row Ex: 0.014340392602534516
# ZeroDivisionError, index: 7597
# ZeroDivisionError, index: 7597 row Ex: 0.014340392602534516
# ZeroDivisionError, index: 7598
# ZeroDivisionError, index: 7598 row Ex: 0.014540392602534515
# ZeroDivisionError, index: 7599
# ZeroDivisionError, index: 7599 row Ex: 0.014540392602534515
# ZeroDivisionError, index: 7600
# ZeroDivisionError, index: 7600 row Ex: 0.014740392602534513
# ZeroDivisionError, index: 7601
# ZeroDivisionError, index: 7601 row Ex: 0.014740392602534513
# ZeroDivisionError, index: 7602
# ZeroDivisionError, index: 7602 row Ex: 0.014840392602534516
# ZeroDivisionError, index: 7603
# ZeroDivisionError, index: 7603 row Ex: 0.014840392602534516
# ZeroDivisionError, index: 7604
# ZeroDivisionError, index: 7604 row Ex: 0.015040392602534515
# ZeroDivisionError, index: 7605
# ZeroDivisionError, index: 7605 row Ex: 0.015040392602534515
# ZeroDivisionError, index: 7606
# ZeroDivisionError, index: 7606 row Ex: 0.015240392602534514
# ZeroDivisionError, index: 7607
# ZeroDivisionError, index: 7607 row Ex: 0.015240392602534514
# ZeroDivisionError, index: 7608
# ZeroDivisionError, index: 7608 row Ex: 0.015440392602534516
# ZeroDivisionError, index: 7609
# ZeroDivisionError, index: 7609 row Ex: 0.015440392602534516
# ZeroDivisionError, index: 7610
# ZeroDivisionError, index: 7610 row Ex: 0.015540392602534515
# ZeroDivisionError, index: 7611
# ZeroDivisionError, index: 7611 row Ex: 0.015540392602534515
# ZeroDivisionError, index: 7612
# ZeroDivisionError, index: 7612 row Ex: 0.015540392602534515
# ZeroDivisionError, index: 7613
# ZeroDivisionError, index: 7613 row Ex: 0.015540392602534515
# ZeroDivisionError, index: 7614
# ZeroDivisionError, index: 7614 row Ex: 0.015740392602534514
# ZeroDivisionError, index: 7615
# ZeroDivisionError, index: 7615 row Ex: 0.015740392602534514
# ZeroDivisionError, index: 7616
# ZeroDivisionError, index: 7616 row Ex: 0.015940392602534516
# ZeroDivisionError, index: 7617
# ZeroDivisionError, index: 7617 row Ex: 0.015940392602534516
# ZeroDivisionError, index: 7618
# ZeroDivisionError, index: 7618 row Ex: 0.016140392602534515
# ZeroDivisionError, index: 7619
# ZeroDivisionError, index: 7619 row Ex: 0.016140392602534515
# ZeroDivisionError, index: 7860
# ZeroDivisionError, index: 7860 row Ex: 0.014348574682716764
# ZeroDivisionError, index: 7861
# ZeroDivisionError, index: 7861 row Ex: 0.014348574682716764
# ZeroDivisionError, index: 7862
# ZeroDivisionError, index: 7862 row Ex: 0.014548574682716767
# ZeroDivisionError, index: 7863
# ZeroDivisionError, index: 7863 row Ex: 0.014548574682716767
# ZeroDivisionError, index: 7864
# ZeroDivisionError, index: 7864 row Ex: 0.014748574682716765
# ZeroDivisionError, index: 7865
# ZeroDivisionError, index: 7865 row Ex: 0.014748574682716765
# ZeroDivisionError, index: 7866
# ZeroDivisionError, index: 7866 row Ex: 0.014948574682716764
# ZeroDivisionError, index: 7867
# ZeroDivisionError, index: 7867 row Ex: 0.014948574682716764
# ZeroDivisionError, index: 7868
# ZeroDivisionError, index: 7868 row Ex: 0.015148574682716767
# ZeroDivisionError, index: 7869
# ZeroDivisionError, index: 7869 row Ex: 0.015148574682716767
# ZeroDivisionError, index: 7870
# ZeroDivisionError, index: 7870 row Ex: 0.015348574682716765
# ZeroDivisionError, index: 7871
# ZeroDivisionError, index: 7871 row Ex: 0.015348574682716765
# ZeroDivisionError, index: 7872
# ZeroDivisionError, index: 7872 row Ex: 0.015548574682716764
# ZeroDivisionError, index: 7873
# ZeroDivisionError, index: 7873 row Ex: 0.015548574682716764
# ZeroDivisionError, index: 7874
# ZeroDivisionError, index: 7874 row Ex: 0.015548574682716764
# ZeroDivisionError, index: 7875
# ZeroDivisionError, index: 7875 row Ex: 0.015548574682716764
# ZeroDivisionError, index: 7876
# ZeroDivisionError, index: 7876 row Ex: 0.015548574682716764
# ZeroDivisionError, index: 7877
# ZeroDivisionError, index: 7877 row Ex: 0.015548574682716764
# ZeroDivisionError, index: 7878
# ZeroDivisionError, index: 7878 row Ex: 0.015648574682716763
# ZeroDivisionError, index: 7879
# ZeroDivisionError, index: 7879 row Ex: 0.015648574682716763
# ZeroDivisionError, index: 7880
# ZeroDivisionError, index: 7880 row Ex: 0.015848574682716766
# ZeroDivisionError, index: 7881
# ZeroDivisionError, index: 7881 row Ex: 0.015848574682716766
# ZeroDivisionError, index: 7882
# ZeroDivisionError, index: 7882 row Ex: 0.015948574682716765
# ZeroDivisionError, index: 7883
# ZeroDivisionError, index: 7883 row Ex: 0.015948574682716765
# ZeroDivisionError, index: 7884
# ZeroDivisionError, index: 7884 row Ex: 0.016148574682716764
# ZeroDivisionError, index: 7885
# ZeroDivisionError, index: 7885 row Ex: 0.016148574682716764
# ZeroDivisionError, index: 7886
# ZeroDivisionError, index: 7886 row Ex: 0.016248574682716763
# ZeroDivisionError, index: 7887
# ZeroDivisionError, index: 7887 row Ex: 0.016248574682716763
# ZeroDivisionError, index: 8138
# ZeroDivisionError, index: 8138 row Ex: 0.01531010924763999
# ZeroDivisionError, index: 8139
# ZeroDivisionError, index: 8139 row Ex: 0.01531010924763999
# ZeroDivisionError, index: 8140
# ZeroDivisionError, index: 8140 row Ex: 0.01551010924763999
# ZeroDivisionError, index: 8141
# ZeroDivisionError, index: 8141 row Ex: 0.01551010924763999
# ZeroDivisionError, index: 8142
# ZeroDivisionError, index: 8142 row Ex: 0.015610109247639989
# ZeroDivisionError, index: 8143
# ZeroDivisionError, index: 8143 row Ex: 0.015610109247639989
# ZeroDivisionError, index: 8144
# ZeroDivisionError, index: 8144 row Ex: 0.01571010924763999
# ZeroDivisionError, index: 8145
# ZeroDivisionError, index: 8145 row Ex: 0.01571010924763999
# ZeroDivisionError, index: 8146
# ZeroDivisionError, index: 8146 row Ex: 0.01571010924763999
# ZeroDivisionError, index: 8147
# ZeroDivisionError, index: 8147 row Ex: 0.01571010924763999
# ZeroDivisionError, index: 8148
# ZeroDivisionError, index: 8148 row Ex: 0.01581010924763999
# ZeroDivisionError, index: 8149
# ZeroDivisionError, index: 8149 row Ex: 0.01581010924763999
# ZeroDivisionError, index: 8150
# ZeroDivisionError, index: 8150 row Ex: 0.01601010924763999
# ZeroDivisionError, index: 8151
# ZeroDivisionError, index: 8151 row Ex: 0.01601010924763999
# ZeroDivisionError, index: 8152
# ZeroDivisionError, index: 8152 row Ex: 0.01621010924763999
# ZeroDivisionError, index: 8153
# ZeroDivisionError, index: 8153 row Ex: 0.01621010924763999
# ZeroDivisionError, index: 8390
# ZeroDivisionError, index: 8390 row Ex: 0.013992884589955304
# ZeroDivisionError, index: 8391
# ZeroDivisionError, index: 8391 row Ex: 0.013992884589955304
# ZeroDivisionError, index: 8392
# ZeroDivisionError, index: 8392 row Ex: 0.014192884589955304
# ZeroDivisionError, index: 8393
# ZeroDivisionError, index: 8393 row Ex: 0.014192884589955304
# ZeroDivisionError, index: 8394
# ZeroDivisionError, index: 8394 row Ex: 0.014392884589955305
# ZeroDivisionError, index: 8395
# ZeroDivisionError, index: 8395 row Ex: 0.014392884589955305
# ZeroDivisionError, index: 8396
# ZeroDivisionError, index: 8396 row Ex: 0.014492884589955304
# ZeroDivisionError, index: 8397
# ZeroDivisionError, index: 8397 row Ex: 0.014492884589955304
# ZeroDivisionError, index: 8398
# ZeroDivisionError, index: 8398 row Ex: 0.014592884589955304
# ZeroDivisionError, index: 8399
# ZeroDivisionError, index: 8399 row Ex: 0.014592884589955304
# ZeroDivisionError, index: 8400
# ZeroDivisionError, index: 8400 row Ex: 0.014692884589955303
# ZeroDivisionError, index: 8401
# ZeroDivisionError, index: 8401 row Ex: 0.014692884589955303
# ZeroDivisionError, index: 8402
# ZeroDivisionError, index: 8402 row Ex: 0.014792884589955306
# ZeroDivisionError, index: 8403
# ZeroDivisionError, index: 8403 row Ex: 0.014792884589955306
# ZeroDivisionError, index: 8404
# ZeroDivisionError, index: 8404 row Ex: 0.014792884589955306
# ZeroDivisionError, index: 8405
# ZeroDivisionError, index: 8405 row Ex: 0.014792884589955306
# ZeroDivisionError, index: 8406
# ZeroDivisionError, index: 8406 row Ex: 0.014892884589955305
# ZeroDivisionError, index: 8407
# ZeroDivisionError, index: 8407 row Ex: 0.014892884589955305
# ZeroDivisionError, index: 8408
# ZeroDivisionError, index: 8408 row Ex: 0.014992884589955305
# ZeroDivisionError, index: 8409
# ZeroDivisionError, index: 8409 row Ex: 0.014992884589955305
# ZeroDivisionError, index: 8410
# ZeroDivisionError, index: 8410 row Ex: 0.014992884589955305
# ZeroDivisionError, index: 8411
# ZeroDivisionError, index: 8411 row Ex: 0.014992884589955305
# ZeroDivisionError, index: 8412
# ZeroDivisionError, index: 8412 row Ex: 0.015192884589955304
# ZeroDivisionError, index: 8413
# ZeroDivisionError, index: 8413 row Ex: 0.015192884589955304
# ZeroDivisionError, index: 8414
# ZeroDivisionError, index: 8414 row Ex: 0.015392884589955306
# ZeroDivisionError, index: 8415
# ZeroDivisionError, index: 8415 row Ex: 0.015392884589955306
# ZeroDivisionError, index: 8416
# ZeroDivisionError, index: 8416 row Ex: 0.015592884589955305
# ZeroDivisionError, index: 8417
# ZeroDivisionError, index: 8417 row Ex: 0.015592884589955305
# ZeroDivisionError, index: 8418
# ZeroDivisionError, index: 8418 row Ex: 0.015592884589955305
# ZeroDivisionError, index: 8419
# ZeroDivisionError, index: 8419 row Ex: 0.015592884589955305
# ZeroDivisionError, index: 8420
# ZeroDivisionError, index: 8420 row Ex: 0.015692884589955304
# ZeroDivisionError, index: 8421
# ZeroDivisionError, index: 8421 row Ex: 0.015692884589955304
# ZeroDivisionError, index: 8422
# ZeroDivisionError, index: 8422 row Ex: 0.015792884589955303
# ZeroDivisionError, index: 8423
# ZeroDivisionError, index: 8423 row Ex: 0.015792884589955303
# ZeroDivisionError, index: 8424
# ZeroDivisionError, index: 8424 row Ex: 0.015792884589955303
# ZeroDivisionError, index: 8425
# ZeroDivisionError, index: 8425 row Ex: 0.015792884589955303
# ZeroDivisionError, index: 8426
# ZeroDivisionError, index: 8426 row Ex: 0.015892884589955303
# ZeroDivisionError, index: 8427
# ZeroDivisionError, index: 8427 row Ex: 0.015892884589955303
# ZeroDivisionError, index: 8428
# ZeroDivisionError, index: 8428 row Ex: 0.015892884589955303
# ZeroDivisionError, index: 8429
# ZeroDivisionError, index: 8429 row Ex: 0.015892884589955303
# ZeroDivisionError, index: 8430
# ZeroDivisionError, index: 8430 row Ex: 0.015992884589955306
# ZeroDivisionError, index: 8431
# ZeroDivisionError, index: 8431 row Ex: 0.015992884589955306
# ZeroDivisionError, index: 8432
# ZeroDivisionError, index: 8432 row Ex: 0.016192884589955304
# ZeroDivisionError, index: 8433
# ZeroDivisionError, index: 8433 row Ex: 0.016192884589955304
# ZeroDivisionError, index: 8434
# ZeroDivisionError, index: 8434 row Ex: 0.016192884589955304
# ZeroDivisionError, index: 8435
# ZeroDivisionError, index: 8435 row Ex: 0.016192884589955304
# ZeroDivisionError, index: 8436
# ZeroDivisionError, index: 8436 row Ex: 0.016192884589955304
# ZeroDivisionError, index: 8437
# ZeroDivisionError, index: 8437 row Ex: 0.016192884589955304
# ZeroDivisionError, index: 8438
# ZeroDivisionError, index: 8438 row Ex: 0.016292884589955304
# ZeroDivisionError, index: 8439
# ZeroDivisionError, index: 8439 row Ex: 0.016292884589955304
# ZeroDivisionError, index: 8440
# ZeroDivisionError, index: 8440 row Ex: 0.016292884589955304
# ZeroDivisionError, index: 8441
# ZeroDivisionError, index: 8441 row Ex: 0.016292884589955304
# ZeroDivisionError, index: 8442
# ZeroDivisionError, index: 8442 row Ex: 0.016392884589955303
# ZeroDivisionError, index: 8443
# ZeroDivisionError, index: 8443 row Ex: 0.016392884589955303
# ZeroDivisionError, index: 8444
# ZeroDivisionError, index: 8444 row Ex: 0.016392884589955303
# ZeroDivisionError, index: 8445
# ZeroDivisionError, index: 8445 row Ex: 0.016392884589955303
# ZeroDivisionError, index: 8446
# ZeroDivisionError, index: 8446 row Ex: 0.016392884589955303
# ZeroDivisionError, index: 8447
# ZeroDivisionError, index: 8447 row Ex: 0.016392884589955303
# ZeroDivisionError, index: 8720
# ZeroDivisionError, index: 8720 row Ex: 0.014318521657961786
# ZeroDivisionError, index: 8721
# ZeroDivisionError, index: 8721 row Ex: 0.014318521657961786
# ZeroDivisionError, index: 8722
# ZeroDivisionError, index: 8722 row Ex: 0.014518521657961789
# ZeroDivisionError, index: 8723
# ZeroDivisionError, index: 8723 row Ex: 0.014518521657961789
# ZeroDivisionError, index: 8724
# ZeroDivisionError, index: 8724 row Ex: 0.014618521657961788
# ZeroDivisionError, index: 8725
# ZeroDivisionError, index: 8725 row Ex: 0.014618521657961788
# ZeroDivisionError, index: 8726
# ZeroDivisionError, index: 8726 row Ex: 0.014718521657961788
# ZeroDivisionError, index: 8727
# ZeroDivisionError, index: 8727 row Ex: 0.014718521657961788
# ZeroDivisionError, index: 8728
# ZeroDivisionError, index: 8728 row Ex: 0.014818521657961787
# ZeroDivisionError, index: 8729
# ZeroDivisionError, index: 8729 row Ex: 0.014818521657961787
# ZeroDivisionError, index: 8730
# ZeroDivisionError, index: 8730 row Ex: 0.014918521657961786
# ZeroDivisionError, index: 8731
# ZeroDivisionError, index: 8731 row Ex: 0.014918521657961786
# ZeroDivisionError, index: 8732
# ZeroDivisionError, index: 8732 row Ex: 0.01501852165796179
# ZeroDivisionError, index: 8733
# ZeroDivisionError, index: 8733 row Ex: 0.01501852165796179
# ZeroDivisionError, index: 8734
# ZeroDivisionError, index: 8734 row Ex: 0.015118521657961789
# ZeroDivisionError, index: 8735
# ZeroDivisionError, index: 8735 row Ex: 0.015118521657961789
# ZeroDivisionError, index: 8736
# ZeroDivisionError, index: 8736 row Ex: 0.015318521657961787
# ZeroDivisionError, index: 8737
# ZeroDivisionError, index: 8737 row Ex: 0.015318521657961787
# ZeroDivisionError, index: 8738
# ZeroDivisionError, index: 8738 row Ex: 0.015618521657961789
# ZeroDivisionError, index: 8739
# ZeroDivisionError, index: 8739 row Ex: 0.015618521657961789
# ZeroDivisionError, index: 8740
# ZeroDivisionError, index: 8740 row Ex: 0.015618521657961789
# ZeroDivisionError, index: 8741
# ZeroDivisionError, index: 8741 row Ex: 0.015618521657961789
# ZeroDivisionError, index: 8742
# ZeroDivisionError, index: 8742 row Ex: 0.015618521657961789
# ZeroDivisionError, index: 8743
# ZeroDivisionError, index: 8743 row Ex: 0.015618521657961789
# ZeroDivisionError, index: 8744
# ZeroDivisionError, index: 8744 row Ex: 0.015618521657961789
# ZeroDivisionError, index: 8745
# ZeroDivisionError, index: 8745 row Ex: 0.015618521657961789
# ZeroDivisionError, index: 8746
# ZeroDivisionError, index: 8746 row Ex: 0.01571852165796179
# ZeroDivisionError, index: 8747
# ZeroDivisionError, index: 8747 row Ex: 0.01571852165796179
# ZeroDivisionError, index: 8748
# ZeroDivisionError, index: 8748 row Ex: 0.01571852165796179
# ZeroDivisionError, index: 8749
# ZeroDivisionError, index: 8749 row Ex: 0.01571852165796179
# ZeroDivisionError, index: 8750
# ZeroDivisionError, index: 8750 row Ex: 0.01571852165796179
# ZeroDivisionError, index: 8751
# ZeroDivisionError, index: 8751 row Ex: 0.01571852165796179
# ZeroDivisionError, index: 8752
# ZeroDivisionError, index: 8752 row Ex: 0.01571852165796179
# ZeroDivisionError, index: 8753
# ZeroDivisionError, index: 8753 row Ex: 0.01571852165796179
# ZeroDivisionError, index: 8754
# ZeroDivisionError, index: 8754 row Ex: 0.01571852165796179
# ZeroDivisionError, index: 8755
# ZeroDivisionError, index: 8755 row Ex: 0.01571852165796179
# ZeroDivisionError, index: 8756
# ZeroDivisionError, index: 8756 row Ex: 0.015818521657961788
# ZeroDivisionError, index: 8757
# ZeroDivisionError, index: 8757 row Ex: 0.015818521657961788
# ZeroDivisionError, index: 8758
# ZeroDivisionError, index: 8758 row Ex: 0.015818521657961788
# ZeroDivisionError, index: 8759
# ZeroDivisionError, index: 8759 row Ex: 0.015818521657961788
# ZeroDivisionError, index: 8760
# ZeroDivisionError, index: 8760 row Ex: 0.015918521657961787
# ZeroDivisionError, index: 8761
# ZeroDivisionError, index: 8761 row Ex: 0.015918521657961787
# ZeroDivisionError, index: 8762
# ZeroDivisionError, index: 8762 row Ex: 0.015918521657961787
# ZeroDivisionError, index: 8763
# ZeroDivisionError, index: 8763 row Ex: 0.015918521657961787
# ZeroDivisionError, index: 8764
# ZeroDivisionError, index: 8764 row Ex: 0.015918521657961787
# ZeroDivisionError, index: 8765
# ZeroDivisionError, index: 8765 row Ex: 0.015918521657961787
# ZeroDivisionError, index: 8766
# ZeroDivisionError, index: 8766 row Ex: 0.015918521657961787
# ZeroDivisionError, index: 8767
# ZeroDivisionError, index: 8767 row Ex: 0.015918521657961787
# ZeroDivisionError, index: 8768
# ZeroDivisionError, index: 8768 row Ex: 0.01611852165796179
# ZeroDivisionError, index: 8769
# ZeroDivisionError, index: 8769 row Ex: 0.01611852165796179
# ZeroDivisionError, index: 8770
# ZeroDivisionError, index: 8770 row Ex: 0.01611852165796179
# ZeroDivisionError, index: 8771
# ZeroDivisionError, index: 8771 row Ex: 0.01611852165796179
# ZeroDivisionError, index: 8772
# ZeroDivisionError, index: 8772 row Ex: 0.01611852165796179
# ZeroDivisionError, index: 8773
# ZeroDivisionError, index: 8773 row Ex: 0.01611852165796179
# ZeroDivisionError, index: 8774
# ZeroDivisionError, index: 8774 row Ex: 0.01621852165796179
# ZeroDivisionError, index: 8775
# ZeroDivisionError, index: 8775 row Ex: 0.01621852165796179
# ZeroDivisionError, index: 8776
# ZeroDivisionError, index: 8776 row Ex: 0.01621852165796179
# ZeroDivisionError, index: 8777
# ZeroDivisionError, index: 8777 row Ex: 0.01621852165796179
# ZeroDivisionError, index: 8778
# ZeroDivisionError, index: 8778 row Ex: 0.01621852165796179
# ZeroDivisionError, index: 8779
# ZeroDivisionError, index: 8779 row Ex: 0.01621852165796179
# ZeroDivisionError, index: 8780
# ZeroDivisionError, index: 8780 row Ex: 0.016318521657961788
# ZeroDivisionError, index: 8781
# ZeroDivisionError, index: 8781 row Ex: 0.016318521657961788
# ZeroDivisionError, index: 8782
# ZeroDivisionError, index: 8782 row Ex: 0.016318521657961788
# ZeroDivisionError, index: 8783
# ZeroDivisionError, index: 8783 row Ex: 0.016318521657961788
# ZeroDivisionError, index: 8784
# ZeroDivisionError, index: 8784 row Ex: 0.016318521657961788
# ZeroDivisionError, index: 8785
# ZeroDivisionError, index: 8785 row Ex: 0.016318521657961788
# ZeroDivisionError, index: 8786
# ZeroDivisionError, index: 8786 row Ex: 0.016318521657961788
# ZeroDivisionError, index: 8787
# ZeroDivisionError, index: 8787 row Ex: 0.016318521657961788

# %%
# save dataframe to csv
# df.to_csv('Data/df_C12_Oct29.csv',index=False)
# df.to_csv('Data/df_C12_Dec10.csv',index=False)
# df.to_csv('Data/df_C12_25Feb24.csv',index=False)
# df.to_csv('Data/df_Yam_40.csv',index=False)
# df.to_csv('Data/df_C12_25Mar14.csv',index=False)
# df.to_csv('Data/df_susa_C12_25May19.csv',index=False)
# df.to_csv('Data/df_C12_25May19.csv',index=False)
df.to_csv('Data/df_C12_25May23.csv',index=False)

# %%
for Q2center in Q2centers:
    response_columns = ['qv','q2','ex','nu','RTTOT','RLTOT','RTQE','RLQE','RTIE','RLIE','RTE','RLE','RTNS','RLNS']
    subprocess.run(['./responseq2'],input=f'{Q2center}\n',text=True)
    subprocess.run(['sleep','0.5'])
    df_response = pd.read_csv('responseq2_output.txt', sep='\s+', header=None, names=response_columns)
    df_response.to_csv(f'Q2edges/Q2edge_{Q2center}.csv',index=False)
    print(Q2center,'done')


for qvcenter in qvcenters:
    response_columns = ['qv','q2','ex','nu','RTTOT','RLTOT','RTQE','RLQE','RTIE','RLIE','RTE','RLE','RTNS','RLNS']
    subprocess.run(['./responseqv'],input=f'{qvcenter}\n',text=True)
    subprocess.run(['sleep','0.5'])
    df_response = pd.read_csv('responseqv_output.txt', sep='\s+', header=None, names=response_columns)
    df_response.to_csv(f'Qvedges/Qvedge_{qvcenter}.csv',index=False)
    print(qvcenter,'done')
# Out:
# 0.01 done
# 0.02 done
# 0.026 done
# 0.04 done
# 0.056 done
# 0.093 done
# 0.12 done
# 0.16 done
# 0.265 done
# 0.38 done
# 0.5 done
# 0.8 done
# 1.25 done
# 1.75 done
# 2.25 done
# 2.75 done
# 3.25 done
# 3.75 done
# 0.1 done
# 0.148 done
# 0.167 done
# 0.205 done
# 0.24 done
# 0.3 done
# 0.38 done
# 0.475 done
# 0.57 done
# 0.649 done
# 0.756 done
# 0.991 done
# 1.619 done
# 1.921 done
# 2.213 done
# 2.5 done
# 2.783 done
# 3.5 done
